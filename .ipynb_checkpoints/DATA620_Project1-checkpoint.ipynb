# %% [markdown]
# ### Bishoy Sokkar
# ### Project 1: Network Analysis of Facebook Page-Page Network
#
# #### Dataset Selection and Description
#
# This project analyzes the MUSAE Facebook Page-Page Network dataset from Stanford's SNAP collection. The dataset is an undirected graph with 22,470 nodes representing verified Facebook pages and 171,002 edges representing mutual "likes". Each node has a categorical attribute indicating the page type: politician, government, company, or tvshow. We will load the dataset, calculate degree and eigenvector centralities, and compare these measures across the page types.
# Part 1: Identify and Load the Network Dataset
# The dataset is identified as the MUSAE Facebook Page-Page Network, which includes categorical information (page type) for each node. To load it, we download the zip file, extract it, and use pandas to read the CSV files. Then, we build the graph using NetworkX.

# %%
import urllib.request
import zipfile
import os
import pandas as pd
import networkx as nx

# Download the zip file
url = "https://snap.stanford.edu/data/facebook_large.zip"
urllib.request.urlretrieve(url, "facebook_large.zip")

# Extract the zip file
with zipfile.ZipFile("facebook_large.zip", 'r') as zip_ref:
    zip_ref.extractall("facebook_large")

# Load edges
edges_path = "facebook_large/musae_facebook_edges.csv"
edges = pd.read_csv(edges_path)

# Load targets (node attributes)
targets_path = "facebook_large/musae_facebook_target.csv"
targets = pd.read_csv(targets_path)

# Create the graph
G = nx.from_pandas_edgelist(edges, 'id_1', 'id_2')

# Add page_type attributes to nodes using the correct 'id' column
page_type_dict = dict(zip(targets['id'], targets['page_type']))
nx.set_node_attributes(G, page_type_dict, 'page_type')

# Verify
print(f"Number of nodes: {G.number_of_nodes()}")
print(f"Number of edges: {G.number_of_edges()}")
print("Unique page types:", set(page_type_dict.values()))
# Out:
# Number of nodes: 22470
# Number of edges: 171002
# Unique page types: {'company', 'politician', 'government', 'tvshow'}

# %%
# Calculate degree centrality
degree_centrality = nx.degree_centrality(G)

# Calculate eigenvector centrality
eigenvector_centrality = nx.eigenvector_centrality(G, max_iter=1000)

# Create a DataFrame with the results
nodes = list(G.nodes())
data = {
    'node': nodes,
    'page_type': [G.nodes[n].get('page_type', 'unknown') for n in nodes],
    'degree_centrality': [degree_centrality[n] for n in nodes],
    'eigenvector_centrality': [eigenvector_centrality[n] for n in nodes]
}
df = pd.DataFrame(data)

# Display the first few rows
df.head()
# Out:
#     node   page_type  degree_centrality  eigenvector_centrality
# 0      0      tvshow           0.000045            1.128138e-07
# 1  18427      tvshow           0.002270            1.184549e-05
# 2      1  government           0.001513            7.961069e-03
# 3  21708  government           0.008679            2.562776e-02
# 4  22208  government           0.009124            3.451845e-02

# %%
import matplotlib.pyplot as plt
from scipy import stats

# Group by page_type and compute means
group_stats_degree = df.groupby('page_type')['degree_centrality'].agg(['mean', 'median', 'std'])
group_stats_eigen = df.groupby('page_type')['eigenvector_centrality'].agg(['mean', 'median', 'std'])

print("Degree Centrality Statistics by Page Type:")
print(group_stats_degree)

print("\nEigenvector Centrality Statistics by Page Type:")
print(group_stats_eigen)

# Boxplots for visualization
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

df.boxplot(column='degree_centrality', by='page_type', ax=axes[0])
axes[0].set_title('Degree Centrality by Page Type')
axes[0].set_ylabel('Degree Centrality')

df.boxplot(column='eigenvector_centrality', by='page_type', ax=axes[1])
axes[1].set_title('Eigenvector Centrality by Page Type')
axes[1].set_ylabel('Eigenvector Centrality')

plt.suptitle('')
plt.show()

# ANOVA test for degree centrality (now with multiple groups)
groups_degree = [df[df['page_type'] == pt]['degree_centrality'] for pt in df['page_type'].unique()]
anova_degree = stats.f_oneway(*groups_degree)
print("\nANOVA for Degree Centrality: F-statistic = {}, p-value = {}".format(anova_degree.statistic, anova_degree.pvalue))

# ANOVA test for eigenvector centrality
groups_eigen = [df[df['page_type'] == pt]['eigenvector_centrality'] for pt in df['page_type'].unique()]
anova_eigen = stats.f_oneway(*groups_eigen)
print("ANOVA for Eigenvector Centrality: F-statistic = {}, p-value = {}".format(anova_eigen.statistic, anova_eigen.pvalue))
# Out:
# Degree Centrality Statistics by Page Type:
#                 mean    median       std
# page_type
# company     0.000330  0.000178  0.000506
# government  0.001151  0.000668  0.001722
# politician  0.000656  0.000312  0.000960
# tvshow      0.000414  0.000223  0.000579
#
# Eigenvector Centrality Statistics by Page Type:
#                 mean    median       std
# page_type
# company     0.000116  0.000002  0.001284
# government  0.004060  0.000203  0.011268
# politician  0.000102  0.000010  0.000563
# tvshow      0.000061  0.000001  0.000360
# ANOVA for Degree Centrality: F-statistic = 672.6006861543144, p-value = 0.0
# ANOVA for Eigenvector Centrality: F-statistic = 632.6024718879918, p-value = 0.0
